# %%
### imports
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
### read in data

x1_train = pd.read_csv("x1_train.csv")
x1_test = pd.read_csv("x1_test.csv")

x2_train = pd.read_csv("x2_train.csv")
x2_test = pd.read_csv("x2_test.csv")

x3_train = pd.read_csv("x3_train.csv")
x3_test = pd.read_csv("x3_test.csv")

x4_train = pd.read_csv("x4_train.csv")
x4_test = pd.read_csv("x4_test.csv")

y_train = pd.read_csv("y_train.csv")
y_test = pd.read_csv("y_test.csv")

# %%
### establish RandomForest models

# model 1
rf1 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# model 2
rf2 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# model 3
rf3 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# model 4
rf4 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# %%
### fit models 

# model 1
rf1.fit(x1_train, y_train)

# model 2
rf2.fit(x2_train, y_train)

# model 3
rf3.fit(x3_train, y_train)

# model 4
rf4.fit(x4_train, y_train)
# Out:
# c:\Users\wells\anaconda3\envs\bmif802\Lib\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\wells\anaconda3\envs\bmif802\Lib\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\wells\anaconda3\envs\bmif802\Lib\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\wells\anaconda3\envs\bmif802\Lib\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
### make predictions

# model 1
y1_pred = rf1.predict(x1_test)

# model 2
y2_pred = rf2.predict(x2_test)

# model 3
y3_pred = rf3.predict(x3_test)

# model 4
y4_pred = rf4.predict(x4_test)

# %%
### evaluate models

# model 1
print("Accuracy:", accuracy_score(y_test, y1_pred))
print(classification_report(y_test, y1_pred))

# model 2
print("Accuracy:", accuracy_score(y_test, y2_pred))
print(classification_report(y_test, y2_pred))

# model 3
print("Accuracy:", accuracy_score(y_test, y3_pred))
print(classification_report(y_test, y3_pred))

# model 4
print("Accuracy:", accuracy_score(y_test, y4_pred))
print(classification_report(y_test, y4_pred))
# Out:
# Accuracy: 0.3249370277078086
#               precision    recall  f1-score   support
#
#  10-15 years       0.23      0.20      0.21        87
#    15+ years       0.36      0.38      0.37       113
#   5-10 years       0.32      0.28      0.30       110
#     <5 years       0.35      0.44      0.39        87
#
#     accuracy                           0.32       397
#    macro avg       0.32      0.32      0.32       397
# weighted avg       0.32      0.32      0.32       397
#
# Accuracy: 0.327455919395466
#               precision    recall  f1-score   support
#
#  10-15 years       0.24      0.20      0.22        87
#    15+ years       0.34      0.35      0.35       113
#   5-10 years       0.32      0.31      0.31       110
#     <5 years       0.38      0.45      0.41        87
#
#     accuracy                           0.33       397
#    macro avg       0.32      0.33      0.32       397
# weighted avg       0.32      0.33      0.32       397
#
# Accuracy: 0.28967254408060455
#               precision    recall  f1-score   support
#
#  10-15 years       0.19      0.15      0.17        87
#    15+ years       0.32      0.33      0.33       113
#   5-10 years       0.25      0.24      0.24       110
#     <5 years       0.35      0.45      0.40        87
#
#     accuracy                           0.29       397
#    macro avg       0.28      0.29      0.28       397
# weighted avg       0.28      0.29      0.28       397
#
# Accuracy: 0.34760705289672544
#               precision    recall  f1-score   support
#
#  10-15 years       0.26      0.22      0.24        87
#    15+ years       0.39      0.42      0.40       113
#   5-10 years       0.35      0.30      0.33       110
#     <5 years       0.35      0.45      0.39        87
#
#     accuracy                           0.35       397
#    macro avg       0.34      0.35      0.34       397
# weighted avg       0.34      0.35      0.34       397

# %%
### plot most important features

# model 1
importances1 = pd.Series(rf1.feature_importances_, index=x1_train.columns)
top_features1 = importances1.sort_values(ascending=False).head(15)

plt.figure(figsize=(8,5))
top_features1.plot(kind="bar")
plt.title("Top Feature Importances - Random Forest")
plt.ylabel("Importance")
plt.show()

# model 2
importances2 = pd.Series(rf2.feature_importances_, index=x2_train.columns)
top_features2 = importances2.sort_values(ascending=False).head(15)

plt.figure(figsize=(8,5))
top_features2.plot(kind="bar")
plt.title("Top Feature Importances - Random Forest")
plt.ylabel("Importance")
plt.show()

# model 3
importances3 = pd.Series(rf3.feature_importances_, index=x3_train.columns)
top_features3 = importances3.sort_values(ascending=False).head(15)

plt.figure(figsize=(8,5))
top_features3.plot(kind="bar")
plt.title("Top Feature Importances - Random Forest")
plt.ylabel("Importance")
plt.show()

# model 4
importances4 = pd.Series(rf4.feature_importances_, index=x4_train.columns)
top_features4 = importances4.sort_values(ascending=False).head(15)

plt.figure(figsize=(8,5))
top_features4.plot(kind="bar")
plt.title("Top Feature Importances - Random Forest")
plt.ylabel("Importance")
plt.show()
